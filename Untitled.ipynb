# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
wn = pd.read_csv('winemag-data_first150k.csv')

# %%
wn.head(5)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
wn.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'country',
#  'description',
#  'designation',
#  'points',
#  'price',
#  'province',
#  'region_1',
#  'region_2',
#  'variety',
#  'winery']

# %%
wn.rename(columns = {'Unnamed: 0': 'index'},inplace = True)

# %%
wn.columns
# Out:
# Index(['index', 'country', 'description', 'designation', 'points', 'price',
#        'province', 'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
wn.head(5)
# Out:
#    index country                                        description  \
# 0      0      US  This tremendous 100% varietal wine hails from ...
# 1      1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      2      US  Mac Watson honors the memory of a wine once ma...
# 3      3      US  This spent 20 months in 30% new French oak, an...
# 4      4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
wn.isnull().sum()
# Out:
# index              0
# country            5
# description        0
# designation    45735
# points             0
# price          13695
# province           5
# region_1       25060
# region_2       89977
# variety            0
# winery             0
# dtype: int64

# %%
wn['variety'].value_counts()
# Out:
# Chardonnay                  14482
# Pinot Noir                  14291
# Cabernet Sauvignon          12800
# Red Blend                   10062
# Bordeaux-style Red Blend     7347
#                             ...
# Carignan-Syrah                  1
# Premsal                         1
# Muskat                          1
# Syrah-Carignan                  1
# Carnelian                       1
# Name: variety, Length: 632, dtype: int64

# %%
wn['designation']
# Out:
# 0                            Martha's Vineyard
# 1         Carodorum Selección Especial Reserva
# 2                Special Selected Late Harvest
# 3                                      Reserve
# 4                                   La Brûlade
#                           ...
# 150925                                     NaN
# 150926                          Cuvée Prestige
# 150927                           Terre di Dora
# 150928                         Grand Brut Rosé
# 150929                                     NaN
# Name: designation, Length: 150930, dtype: object

# %%
wn['country'].value_counts().head(5).plot.bar()
# Out:
# <AxesSubplot: >

# %%
wn.groupby(['country'])['points'].mean().head(10).sort_values(ascending= False)
# Out:
# country
# Austria                   89.276742
# Canada                    88.239796
# Albania                   88.000000
# Australia                 87.892475
# Chile                     86.296768
# Argentina                 85.996093
# Bulgaria                  85.467532
# Bosnia and Herzegovina    84.750000
# Brazil                    83.240000
# China                     82.000000
# Name: points, dtype: float64

# %%
len(wn)
# Out:
# 150930

# %%
len(wn['designation'].unique())
# Out:
# 30622

# %%
wn['designation']
# Out:
# 0                            Martha's Vineyard
# 1         Carodorum Selección Especial Reserva
# 2                Special Selected Late Harvest
# 3                                      Reserve
# 4                                   La Brûlade
#                           ...
# 150925                                     NaN
# 150926                          Cuvée Prestige
# 150927                           Terre di Dora
# 150928                         Grand Brut Rosé
# 150929                                     NaN
# Name: designation, Length: 150930, dtype: object

# %%
wn.groupby(['country'])['price'].mean().sort_values(ascending= False)
# Out:
# country
# US-France                 50.000000
# England                   47.500000
# France                    45.619885
# Hungary                   44.204348
# Luxembourg                40.666667
# Germany                   39.011078
# Italy                     37.547913
# Canada                    34.628866
# US                        33.653808
# Israel                    31.304918
# Australia                 31.258480
# Austria                   31.192106
# Mexico                    29.095238
# Slovenia                  28.061728
# Spain                     27.048529
# Switzerland               26.500000
# Portugal                  26.332615
# Uruguay                   25.847059
# Turkey                    25.800000
# Lebanon                   25.432432
# Serbia                    24.285714
# New Zealand               24.173290
# Japan                     24.000000
# Croatia                   23.108434
# Greece                    21.747706
# South Africa              21.130532
# ...

# %%
wn_90 = wn[wn['points']> 90]

# %%
wn['winery'].value_counts().reset_index(name='counts')
# Out:
#                        index  counts
# 0            Williams Selyem     374
# 1                 Testarossa     274
# 2                 DFJ Vinhos     258
# 3      Chateau Ste. Michelle     225
# 4             Columbia Crest     217
# ...                      ...     ...
# 14805       Republic of Wine       1
# 14806          Prince Michel       1
# 14807            Glass House       1
# 14808       Jones von Drehle       1
# 14809             White Knot       1
#
# [14810 rows x 2 columns]

# %%
wn.groupby(['winery'])['points'].mean().head(30)
# Out:
# winery
# '37 Cellars                88.000000
# 1+1=3                      83.800000
# 10 Knots                   84.375000
# 1000 Stories               90.000000
# 1040FU                     82.000000
# 1070 Green                 88.000000
# 10Span                     83.000000
# 12 Linajes                 87.428571
# 12C Wines                  93.000000
# 14 Hands                   87.277778
# 16X20                      85.500000
# 1789 Wines                 91.000000
# 181                        84.000000
# 1848 Winery                89.000000
# 1850                       91.000000
# 1919                       83.000000
# 2 Brothers                 82.666667
# 2 Cocky Sisters            85.000000
# 2 Copas                    81.000000
# 2 Lads                     83.000000
# 2 Up                       85.200000
# 21 Grams                   93.000000
# 25 Lagunas                 81.000000
# 2820 Wine Co.              83.750000
# 2Hawk                      90.000000
# ...

# %%
wn[wn['country'] == 'Austria']
# Out:
#          index  country                                        description  \
# 582        582  Austria  Pepper and cinnamon strike first, before beaut...
# 587        587  Austria  Juicy, vivid black cherry fruit appears on the...
# 588        588  Austria  Upon first pour, this only shows some earthy h...
# 595        595  Austria  Oak leaf, tart strawberry and supple vanilla a...
# 1179      1179  Austria  Wonderfully aromatic fruit rises from the glas...
# ...        ...      ...                                                ...
# 149361  149361  Austria  Pungent on the nose, offering up hints of gras...
# 149364  149364  Austria  Creamy-textured and more rounded than you migh...
# 149458  149458  Austria  Bold blackberry fruit is framed by notes of gr...
# 149523  149523  Austria  Not quite in synch, with hard, stony aromas ye...
# 149531  149531  Austria  Light and fresh, but seems to lack a bit of in...
#
# ...

# %%
wn_90['country'].value_counts()
# Out:
# US              14427
# France           6554
# Italy            5202
# Portugal         1116
# Spain             967
# Australia         893
# Austria           886
# Germany           620
# Argentina         492
# Chile             391
# New Zealand       342
# South Africa      184
# Hungary            46
# Israel             44
# Canada             35
# Greece             10
# England             9
# Slovenia            5
# Turkey              3
# Mexico              3
# Lebanon             2
# Georgia             2
# Morocco             1
# India               1
# Croatia             1
# Romania             1
# Name: country, dtype: int64

# %%
wn[wn['winery'] == 'Meinklang']
# Out:
#       index  country                                        description  \
# 587     587  Austria  Juicy, vivid black cherry fruit appears on the...
# 4328   4328  Austria  Fresh blueberry and plum play on nose and pala...
# 5970   5970  Austria  Ripe blackberry notes dominate this wine's nos...
#
#         designation  points  price    province region_1 region_2  \
# 587             NaN      93   19.0  Burgenland      NaN      NaN
# 4328            NaN      91   19.0  Burgenland      NaN      NaN
# 5970  Burgenlandrot      90   15.0  Burgenland      NaN      NaN
#
#                  variety     winery
# 587        Blauburgunder  Meinklang
# 4328       Blaufränkisch  Meinklang
# 5970  Austrian Red Blend  Meinklang

# %%
wn['winery'].unique().shape[0]
# Out:
# 14810

# %%
wn_90.groupby(['country'])['points'].mean().sort_values(ascending = False)
# Out:
# country
# Morocco         93.000000
# England         92.888889
# France          92.665548
# US              92.481874
# Austria         92.332957
# Italy           92.321030
# Germany         92.245161
# Australia       92.229563
# Hungary         92.217391
# Spain           92.182006
# Portugal        92.067204
# Argentina       92.028455
# Georgia         92.000000
# Romania         92.000000
# South Africa    91.663043
# Chile           91.616368
# New Zealand     91.540936
# Canada          91.428571
# Israel          91.409091
# Slovenia        91.400000
# Mexico          91.333333
# Turkey          91.333333
# Greece          91.200000
# India           91.000000
# Lebanon         91.000000
# Croatia         91.000000
# Name: points, dtype: float64

# %%
wn_90[wn_90['country'] == 'England']
# Out:
#        index  country                                        description  \
# 28800  28800  England  Gentle white blossom, white currant and Golden...
# 28801  28801  England  A lifting mix of golden, ripe apple, chamomile...
# 28818  28818  England  Sophisticated aromas of Golden Pearmain apples...
# 28822  28822  England  Both the fruit and the aromatic foliage of wil...
# 28828  28828  England  This has the crunchy, enticing freshness of th...
# 30358  30358  England  This wine resonates earth, apple, chalk and oa...
# 30970  30970  England  Creamy notes of Golden Pearmain apple, shortcr...
# 31817  31817  England  Crisp green apple flavors are immediately appa...
# 32132  32132  England  An abundance of apple flavors—green, golden an...
#
#                          designation  points  price province region_1  \
# 28800                Blanc de Blancs      94   45.0  England      NaN
# 28801  South Ridge Cuvée Merret Brut      94   38.0  England      NaN
# ...

# %%
wn.groupby(['country'])['price'].mean().sort_values(ascending= False)
# Out:
# country
# US-France                 50.000000
# England                   47.500000
# France                    45.619885
# Hungary                   44.204348
# Luxembourg                40.666667
# Germany                   39.011078
# Italy                     37.547913
# Canada                    34.628866
# US                        33.653808
# Israel                    31.304918
# Australia                 31.258480
# Austria                   31.192106
# Mexico                    29.095238
# Slovenia                  28.061728
# Spain                     27.048529
# Switzerland               26.500000
# Portugal                  26.332615
# Uruguay                   25.847059
# Turkey                    25.800000
# Lebanon                   25.432432
# Serbia                    24.285714
# New Zealand               24.173290
# Japan                     24.000000
# Croatia                   23.108434
# Greece                    21.747706
# South Africa              21.130532
# ...

# %%
wn.head(5)
# Out:
#    index country                                        description  \
# 0      0      US  This tremendous 100% varietal wine hails from ...
# 1      1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      2      US  Mac Watson honors the memory of a wine once ma...
# 3      3      US  This spent 20 months in 30% new French oak, an...
# 4      4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
wn.isnull().sum()
# Out:
# index              0
# country            5
# description        0
# designation    45735
# points             0
# price          13695
# province           5
# region_1       25060
# region_2       89977
# variety            0
# winery             0
# dtype: int64

# %%
wn_ct_po = wn.groupby(['country'])['points'].mean().sort_values(ascending= False).head(10).reset_index(name = 'points')
wn_ct_po
# Out:
#     country     points
# 0   England  92.888889
# 1   Austria  89.276742
# 2    France  88.925870
# 3   Germany  88.626427
# 4     Italy  88.413664
# 5    Canada  88.239796
# 6  Slovenia  88.234043
# 7   Morocco  88.166667
# 8    Turkey  88.096154
# 9  Portugal  88.057685

# %%
f,ax = plt.subplots(figsize = (10,10))
sns.barplot(data = wn_ct_po,x = 'country',y = 'points',palette= 'Set2')
# Out:
# <AxesSubplot: xlabel='country', ylabel='points'>

# %%
wn_ct_pr = wn.groupby(['country'])['price'].mean().sort_values(ascending= False).head(10).reset_index(name = 'points')
wn_ct_pr
# Out:
#       country     points
# 0   US-France  50.000000
# 1     England  47.500000
# 2      France  45.619885
# 3     Hungary  44.204348
# 4  Luxembourg  40.666667
# 5     Germany  39.011078
# 6       Italy  37.547913
# 7      Canada  34.628866
# 8          US  33.653808
# 9      Israel  31.304918

# %%
wn.shape[0]
# Out:
# 150930

# %%
wn_prna = wn.dropna(axis ='index',how = 'all',subset='price')

# %%
wn_prna[wn_prna['country'] == 'US-France']
# Out:
#          index    country                                        description  \
# 144054  144054  US-France  Defies categorization, in more ways than one. ...
#
#        designation  points  price                       province region_1  \
# 144054         NaN      88   50.0  Santa Barbara County-Condrieu      NaN
#
#        region_2   variety  winery
# 144054      NaN  Viognier  Deux C

# %%
wn_prna
# Out:
#          index country                                        description  \
# 0            0      US  This tremendous 100% varietal wine hails from ...
# 1            1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            2      US  Mac Watson honors the memory of a wine once ma...
# 3            3      US  This spent 20 months in 30% new French oak, an...
# 4            4  France  This is the top wine from La Bégude, named aft...
# ...        ...     ...                                                ...
# 150925  150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  150926  France  Offers an intriguing nose with ginger, lime an...
# 150927  150927   Italy  This classic example comes from a cru vineyard...
# 150928  150928  France  A perfect salmon shade, with scents of peaches...
# 150929  150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# ...

# %%
wn_prna_1 = wn_prna['country'].value_counts().reset_index(name = 'counts')
wn_prna_2 = wn_prna_1[wn_prna_1['counts'] > 10 ]['index'].tolist()

# %%
wn_prna_3 = wn_prna[wn_prna['country'].isin(wn_prna_2)]
wn_prna_3
# Out:
#          index country                                        description  \
# 0            0      US  This tremendous 100% varietal wine hails from ...
# 1            1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            2      US  Mac Watson honors the memory of a wine once ma...
# 3            3      US  This spent 20 months in 30% new French oak, an...
# 4            4  France  This is the top wine from La Bégude, named aft...
# ...        ...     ...                                                ...
# 150925  150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  150926  France  Offers an intriguing nose with ginger, lime an...
# 150927  150927   Italy  This classic example comes from a cru vineyard...
# 150928  150928  France  A perfect salmon shade, with scents of peaches...
# 150929  150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# ...

# %%
wn_prna_4 = wn_prna_3.groupby(['country'])['price'].mean().sort_values(ascending = False).reset_index()
wn_prna_4
# Out:
#          country      price
# 0         France  45.619885
# 1        Hungary  44.204348
# 2        Germany  39.011078
# 3          Italy  37.547913
# 4         Canada  34.628866
# 5             US  33.653808
# 6         Israel  31.304918
# 7      Australia  31.258480
# 8        Austria  31.192106
# 9         Mexico  29.095238
# 10      Slovenia  28.061728
# 11         Spain  27.048529
# 12      Portugal  26.332615
# 13       Uruguay  25.847059
# 14        Turkey  25.800000
# 15       Lebanon  25.432432
# 16        Serbia  24.285714
# 17   New Zealand  24.173290
# 18       Croatia  23.108434
# 19        Greece  21.747706
# 20  South Africa  21.130532
# 21     Argentina  20.794881
# 22        Brazil  19.920000
# 23         Chile  19.344780
# 24       Morocco  18.833333
# 25       Georgia  18.581395
# 26       Romania  16.395683
# 27        Cyprus  15.483871
# 28       Moldova  15.366197
# 29     Macedonia  15.312500
# 30      Bulgaria  11.545455

# %%
f,ax = plt.subplots(figsize = (30,10))

sns.barplot(data = wn_prna_4, x = 'country', y = 'price' )
# Out:
# <AxesSubplot: xlabel='country', ylabel='price'>

# %%
wn_prna.groupby(['country'])['price'].mean().sort_values(ascending = False)
# Out:
# country
# US-France                 50.000000
# England                   47.500000
# France                    45.619885
# Hungary                   44.204348
# Luxembourg                40.666667
# Germany                   39.011078
# Italy                     37.547913
# Canada                    34.628866
# US                        33.653808
# Israel                    31.304918
# Australia                 31.258480
# Austria                   31.192106
# Mexico                    29.095238
# Slovenia                  28.061728
# Spain                     27.048529
# Switzerland               26.500000
# Portugal                  26.332615
# Uruguay                   25.847059
# Turkey                    25.800000
# Lebanon                   25.432432
# Serbia                    24.285714
# New Zealand               24.173290
# Japan                     24.000000
# Croatia                   23.108434
# Greece                    21.747706
# South Africa              21.130532
# ...

# %%
wn_prna_3
# Out:
#          index country                                        description  \
# 0            0      US  This tremendous 100% varietal wine hails from ...
# 1            1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            2      US  Mac Watson honors the memory of a wine once ma...
# 3            3      US  This spent 20 months in 30% new French oak, an...
# 4            4  France  This is the top wine from La Bégude, named aft...
# ...        ...     ...                                                ...
# 150925  150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  150926  France  Offers an intriguing nose with ginger, lime an...
# 150927  150927   Italy  This classic example comes from a cru vineyard...
# 150928  150928  France  A perfect salmon shade, with scents of peaches...
# 150929  150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# ...

# %%
wn_prna_3['efficiency'] = wn_prna_3['points']/wn_prna_3['price']
wn_prna_3
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4928\3539106584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wn_prna_3['efficiency'] = wn_prna_3['points']/wn_prna_3['price']
#          index country                                        description  \
# 0            0      US  This tremendous 100% varietal wine hails from ...
# 1            1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2            2      US  Mac Watson honors the memory of a wine once ma...
# 3            3      US  This spent 20 months in 30% new French oak, an...
# 4            4  France  This is the top wine from La Bégude, named aft...
# ...        ...     ...                                                ...
# ...

# %%
wn_prna_3.sort_values(by = 'efficiency',ascending = False)
# Out:
#        index   country                                        description  \
# 73417  73417   Romania  Notes of sun-dried hay and green flower highli...
# 48655  48655        US  There's a lot going on in this Merlot, which i...
# 99045  99045  Portugal  This is a ripe-fruited wine, rich with dried f...
# 25645  25645        US  There's a lot going on in this Merlot, which i...
# 80185  80185        US  There's a lot going on in this Merlot, which i...
# ...      ...       ...                                                ...
# 83536  83536    France  A wine that has created its own universe. It h...
# 51886  51886    France  A wine that has created its own universe. It h...
# 34922  34922    France  A massive wine for Margaux, packed with tannin...
# 13318  13318        US  The nose on this single-vineyard wine from a s...
# 34920  34920    France  A big, powerful wine that sums up the richness...
#
#                designation  points   price         province     region_1  \
# ...

# %%
wn_prna_3.groupby(['country'])['efficiency'].mean().sort_values(ascending = False).head(10)
# Out:
# country
# Bulgaria     8.369827
# Romania      7.709988
# Moldova      6.645491
# Chile        6.065113
# Argentina    5.906814
# Macedonia    5.863742
# Cyprus       5.857162
# Portugal     5.595943
# Morocco      5.559404
# Georgia      5.525726
# Name: efficiency, dtype: float64

# %%
wn_prna_5 =  wn_prna_3['winery'].value_counts().reset_index().rename(columns = {'index' : 'winery','winery': 'counts'})

# %%
wn_prna_6 = wn_prna_5[wn_prna_5['counts'] > 42]

# %%
wn_prna_7 = wn_prna_3[wn_prna_3['winery'].isin(wn_prna_6['winery'].tolist())]

# %%
wn_prna_6['winery'].tolist()
# Out:
# ['Williams Selyem',
#  'Testarossa',
#  'DFJ Vinhos',
#  'Chateau Ste. Michelle',
#  'Kendall-Jackson',
#  'Columbia Crest',
#  'Concha y Toro',
#  'Trapiche',
#  'Bouchard Père & Fils',
#  'De Loach',
#  'Joseph Drouhin',
#  'Kenwood',
#  'Cameron Hughes',
#  'Morgan',
#  'Louis Latour',
#  "D'Arenberg",
#  'Dry Creek Vineyard',
#  'Concannon',
#  'Robert Mondavi',
#  'Martin Ray',
#  'Wines & Winemakers',
#  'Errazuriz',
#  "L'Ecole No. 41",
#  'Iron Horse',
#  'Montes',
#  'Waterbrook',
#  'Renwood',
#  'Santa Rita',
#  'Calera',
#  'Yalumba',
#  'Hogue',
#  'Gary Farrell',
#  'Santa Ema',
#  'Sineann',
#  'Bodega Norton',
#  'Seven Hills',
#  'Rodney Strong',
#  'Wellington',
#  'Novy',
#  'Viu Manent',
#  'Adelaida',
#  'Saint Clair',
#  'Planeta',
#  'Thomas Fogarty',
#  'Dutton-Goldfield',
#  'Penfolds',
#  'Brander',
#  'Fess Parker',
#  'Beringer',
#  'J. Lohr',
#  'Peachy Canyon',
#  'Siduri',
#  'Tamarack Cellars',
#  'Bernardus',
#  'Clos La Chance',
#  'EOS',
# ...

# %%
wn_prna_7.groupby(['winery'])['points'].mean().sort_values(ascending = False)
# Out:
# winery
# Cayuse              95.240741
# Le Macchiole        94.700000
# Leonetti Cellar     93.868852
# Domaine Leflaive    93.574468
# Betz Family         93.436364
#                       ...
# Peirano             83.685714
# Pietra Santa        83.574468
# Chaddsford          83.456522
# Ca' Momi            83.279070
# Funky Llama         82.681159
# Name: points, Length: 593, dtype: float64

# %%
wn_prna_7
# Out:
#          index      country  \
# 3            3           US
# 14          14           US
# 19          19           US
# 21          21        Spain
# 25          25  New Zealand
# ...        ...          ...
# 150905  150905        Chile
# 150914  150914           US
# 150915  150915           US
# 150916  150916           US
# 150925  150925        Italy
#
#                                               description  \
# 3       This spent 20 months in 30% new French oak, an...
# 14      With its sophisticated mix of mineral, acid an...
# 19      This fresh and lively medium-bodied wine is be...
# 21      Alluring, complex and powerful aromas of grill...
# 25      Yields were down in 2015, but intensity is up,...
# ...                                                   ...
# 150905  There's not much point in making a reserve-sty...
# 150914  Old-gold in color, and thick and syrupy. The a...
# 150915  Decades ago, Beringer’s then-winemaker Myron N...
# ...

# %%
wn_prna_7['province'].value_counts()
# Out:
# California                  18418
# Washington                   4669
# Mendoza Province             2085
# Oregon                       1666
# Burgundy                     1607
#                             ...
# Vinho da Mesa                   1
# Casablanca-Curicó Valley        1
# America                         1
# Tasmania                        1
# South Africa                    1
# Name: province, Length: 175, dtype: int64

# %%
f,ax = plt.subplots(figsize = (10,10))

sns.scatterplot(data = wn_prna_7, x = 'points', y = 'price')
# Out:
# <AxesSubplot: xlabel='points', ylabel='price'>

# %%
wn_prna_7.groupby(['country'])['province'].value_counts()
# Out:
# country    province
# Argentina  Mendoza Province     2085
#            Other                 316
# Australia  South Australia       833
#            Australia Other       138
#            Western Australia      57
#                                 ...
# US         Oregon               1666
#            New York              835
#            Pennsylvania           46
#            Washington-Oregon       2
#            America                 1
# Name: province, Length: 175, dtype: int64

# %%
wn_prna_7
# Out:
#          index      country  \
# 3            3           US
# 14          14           US
# 19          19           US
# 21          21        Spain
# 25          25  New Zealand
# ...        ...          ...
# 150905  150905        Chile
# 150914  150914           US
# 150915  150915           US
# 150916  150916           US
# 150925  150925        Italy
#
#                                               description  \
# 3       This spent 20 months in 30% new French oak, an...
# 14      With its sophisticated mix of mineral, acid an...
# 19      This fresh and lively medium-bodied wine is be...
# 21      Alluring, complex and powerful aromas of grill...
# 25      Yields were down in 2015, but intensity is up,...
# ...                                                   ...
# 150905  There's not much point in making a reserve-sty...
# 150914  Old-gold in color, and thick and syrupy. The a...
# 150915  Decades ago, Beringer’s then-winemaker Myron N...
# ...

# %%
wn_prna_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43487 entries, 3 to 150925
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        43487 non-null  int64
#  1   country      43487 non-null  object
#  2   description  43487 non-null  object
#  3   designation  33108 non-null  object
#  4   points       43487 non-null  int64
#  5   price        43487 non-null  float64
#  6   province     43487 non-null  object
#  7   region_1     35748 non-null  object
#  8   region_2     25461 non-null  object
#  9   variety      43487 non-null  object
#  10  winery       43487 non-null  object
#  11  efficiency   43487 non-null  float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 4.3+ MB

# %%
f,ax = plt.subplots(figsize = (10,10))

sns.scatterplot(data = wn_prna_7, x= 'points', y = 'efficiency')
# Out:
# <AxesSubplot: xlabel='points', ylabel='efficiency'>

# %%
wn_us = wn_prna_7[wn_prna_7['country'] == 'US']
wn_us
# Out:
#          index country                                        description  \
# 3            3      US  This spent 20 months in 30% new French oak, an...
# 14          14      US  With its sophisticated mix of mineral, acid an...
# 19          19      US  This fresh and lively medium-bodied wine is be...
# 27          27      US  Focused and dense, this intense wine captures ...
# 29          29      US  This standout Rocks District wine brings earth...
# ...        ...     ...                                                ...
# 150873  150873      US  With a color akin to the soft pink of ripe pea...
# 150889  150889      US  A bizarre style of wine. The aromas are Port-l...
# 150914  150914      US  Old-gold in color, and thick and syrupy. The a...
# 150915  150915      US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916  150916      US  An impressive wine that presents a full bouque...
#
#                         designation  points  price    province  \
# ...

# %%
wn_us['province'].unique()
# Out:
# array(['Oregon', 'California', 'Washington', 'New York', 'Pennsylvania',
#        'America', 'Washington-Oregon'], dtype=object)

# %%
print(wn_us['efficiency'].min())
print(wn_us['efficiency'].max())
# Out:
# 0.372
# 16.8

# %%
wn_us_ef = wn_us.groupby(['variety'])['efficiency'].value_counts().sort_values(ascending = False).reset_index(name = 'counts').sort_values(by = 'efficiency',ascending = False)
wn_us_ef
# Out:
#                  variety  efficiency  counts
# 2866  Cabernet Sauvignon   16.800000       3
# 6015          Chardonnay   14.166667       1
# 4920      Gewürztraminer   12.857143       1
# 6212           Red Blend   12.714286       1
# 2203            Riesling   12.571429       3
# ...                  ...         ...     ...
# 5802  Cabernet Sauvignon    0.408696       1
# 5804  Cabernet Sauvignon    0.404651       1
# 2685  Cabernet Sauvignon    0.380000       3
# 3315  Cabernet Sauvignon    0.379592       2
# 2684  Cabernet Sauvignon    0.372000       3
#
# [6257 rows x 3 columns]

# %%
f,ax = plt.subplots(figsize = (10,10))

sns.scatterplot(data = wn_us_ef, x= 'counts', y = 'efficiency')
# Out:
# <AxesSubplot: xlabel='counts', ylabel='efficiency'>

# %%
wn_us['province'].value_counts()
# Out:
# California           18418
# Washington            4669
# Oregon                1666
# New York               835
# Pennsylvania            46
# Washington-Oregon        2
# America                  1
# Name: province, dtype: int64

# %%
wn_prna_7.corr()
# Out:
#                index    points     price  efficiency
# index       1.000000 -0.094793 -0.051054    0.061394
# points     -0.094793  1.000000  0.493047   -0.547625
# price      -0.051054  0.493047  1.000000   -0.590995
# efficiency  0.061394 -0.547625 -0.590995    1.000000

# %%
wn_prna_7.head(5)
# Out:
#     index      country                                        description  \
# 3       3           US  This spent 20 months in 30% new French oak, an...
# 14     14           US  With its sophisticated mix of mineral, acid an...
# 19     19           US  This fresh and lively medium-bodied wine is be...
# 21     21        Spain  Alluring, complex and powerful aromas of grill...
# 25     25  New Zealand  Yields were down in 2015, but intensity is up,...
#
#                 designation  points  price        province           region_1  \
# 3                   Reserve      96   65.0          Oregon  Willamette Valley
# 14           Grace Vineyard      95  185.0          Oregon       Dundee Hills
# 19     Gap's Crown Vineyard      95   75.0      California       Sonoma Coast
# 21  Prado Enea Gran Reserva      95   79.0  Northern Spain              Rioja
# 25          Maté's Vineyard      94   57.0           Kumeu                NaN
#
# ...

# %%
wn_prna_7.groupby(['variety'])['points'].mean().sort_values(ascending = False)
# Out:
# variety
# Cabernet Franc-Merlot    93.0
# Roussanne-Viognier       93.0
# Sirica                   93.0
# Sämling                  93.0
# Gelber Muskateller       92.0
#                          ...
# Teroldego                83.0
# Roussanne-Marsanne       82.0
# Grolleau                 82.0
# Vilana                   81.0
# Chambourcin              81.0
# Name: points, Length: 311, dtype: float64

# %%
wn_prna_7.groupby(['variety'])['efficiency'].mean().sort_values(ascending = False)
# Out:
# variety
# Tempranillo-Merlot                    11.690476
# Cabernet Sauvignon and Tinta Roriz    10.750000
# Symphony                              10.541667
# Viura-Chardonnay                      10.111111
# Portuguese Rosé                       10.108252
#                                         ...
# Nasco                                  1.415385
# Cabernet Franc-Merlot                  1.162500
# Carignan-Syrah                         1.150000
# Gelber Muskateller                     0.929293
# Mission                                0.642857
# Name: efficiency, Length: 311, dtype: float64

# %%
wn_us_ef
# Out:
#                  variety  efficiency  counts
# 2866  Cabernet Sauvignon   16.800000       3
# 6015          Chardonnay   14.166667       1
# 4920      Gewürztraminer   12.857143       1
# 6212           Red Blend   12.714286       1
# 2203            Riesling   12.571429       3
# ...                  ...         ...     ...
# 5802  Cabernet Sauvignon    0.408696       1
# 5804  Cabernet Sauvignon    0.404651       1
# 2685  Cabernet Sauvignon    0.380000       3
# 3315  Cabernet Sauvignon    0.379592       2
# 2684  Cabernet Sauvignon    0.372000       3
#
# [6257 rows x 3 columns]

# %%
f,ax = plt.subplots(figsize = (10,10))

sns.scatterplot(data = wn_prna_7, x= 'points', y = 'price')
# Out:
# <AxesSubplot: xlabel='points', ylabel='price'>
